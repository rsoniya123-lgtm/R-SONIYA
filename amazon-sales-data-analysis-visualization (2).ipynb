# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
sns.set_theme(style="whitegrid")

# %%
df=pd.read_csv('Amazon Sale Report.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12068\991315577.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Amazon Sale Report.csv')

# %% [markdown]
# ## Data Characteristic

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %% [markdown]
# Category: Type of product. (String) Size: Size of the product.
#
# (String) Date: Date of the sale.
#
# (Date) Status: Status of the sale.
#
# (String) Fulfilment: Method of fulfilment.
#
# (String) Style: Style of the product.
#
# (String) SKU: Stock Keeping Unit.
#
# (String) ASIN: Amazon Standard Identification Number.
#
# (String) Courier Status: Status of the courier.
#
# (String) Qty: Quantity of the product.
#
# (Integer) Amount: Amount of the sale.
#
# (Float) B2B: Business to business sale.
#
# (Boolean) Currency: The currency used for the sale. (String)

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.describe(include=('O'))
# Out:
#                    Order ID      Date   Status Fulfilment Sales Channel   \
# count                128975    128975   128975     128975         128975
# unique               120378        91       13          2              2
# top     171-5057375-2831560  05-03-22  Shipped     Amazon      Amazon.in
# freq                     12      2085    77804      89698         128851
#
#        ship-service-level    Style           SKU Category    Size        ASIN  \
# count              128975   128975        128975   128975  128975      128975
# unique                  2     1377          7195        9      11        7190
# top             Expedited  JNE3797  JNE3797-KR-L      Set       M  B09SDXFFQ1
# freq                88615     4224           773    50284   22711         773
#
#        Courier Status currency  ship-city   ship-state ship-country  \
# count          122103   121180     128942       128942       128942
# unique              3        1       8955           69            1
# ...

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.size
# Out:
# 3095400

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique().to_frame(name='Count of unique values')
# Out:
#                     Count of unique values
# index                               128975
# Order ID                            120378
# Date                                    91
# Status                                  13
# Fulfilment                               2
# Sales Channel                            2
# ship-service-level                       2
# Style                                 1377
# SKU                                   7195
# Category                                 9
# Size                                    11
# ASIN                                  7190
# Courier Status                           3
# Qty                                     10
# currency                                 1
# Amount                                1410
# ship-city                             8955
# ship-state                              69
# ship-postal-code                      9459
# ship-country                             1
# promotion-ids                         5787
# ...

# %%
df.drop(columns= ['index','Unnamed: 22', 'fulfilled-by', 'ship-country', 'currency'], inplace = True)

# %%
df.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# promotion-ids         49153
# B2B                       0
# dtype: int64

# %%
df[df.duplicated(['Order ID','ASIN'], keep=False)]
# Out:
#                   Order ID      Date     Status Fulfilment Sales Channel   \
# 30660  406-0372545-6086735  04-12-22  Cancelled     Amazon      Amazon.in
# 30661  406-0372545-6086735  04-12-22  Cancelled     Amazon      Amazon.in
# 41291  408-0373839-4433120  04-05-22  Cancelled     Amazon      Amazon.in
# 41292  408-0373839-4433120  04-05-22  Cancelled     Amazon      Amazon.in
# 52330  407-8364731-6449117  05-29-22    Shipped     Amazon      Amazon.in
# 52333  407-8364731-6449117  05-29-22    Shipped     Amazon      Amazon.in
# 79844  171-9628368-5329958  05-07-22  Cancelled     Amazon      Amazon.in
# 79845  171-9628368-5329958  05-07-22  Cancelled     Amazon      Amazon.in
# 85790  171-3249942-2207542  05-03-22    Shipped     Amazon      Amazon.in
# 85791  171-3249942-2207542  05-03-22    Shipped     Amazon      Amazon.in
# 86418  405-8669298-3850736  05-03-22    Shipped     Amazon      Amazon.in
# 86419  405-8669298-3850736  05-03-22    Shipped     Amazon      Amazon.in
# ...

# %%
df.drop_duplicates(['Order ID','ASIN'],inplace = True,ignore_index=True)

# %%
df.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# Amount                 7792
# ship-city                33
# ship-state               33
# ship-postal-code         33
# promotion-ids         49150
# B2B                       0
# dtype: int64

# %%
df["Courier Status"]
# Out:
# 0             NaN
# 1         Shipped
# 2         Shipped
# 3             NaN
# 4         Shipped
#            ...
# 128963    Shipped
# 128964    Shipped
# 128965    Shipped
# 128966    Shipped
# 128967    Shipped
# Name: Courier Status, Length: 128968, dtype: object

# %%
df['Courier Status'].fillna('unknown',inplace=True)

# %%
df["Amount"]
# Out:
# 0          647.62
# 1          406.00
# 2          329.00
# 3          753.33
# 4          574.00
#            ...
# 128963     517.00
# 128964     999.00
# 128965     690.00
# 128966    1199.00
# 128967     696.00
# Name: Amount, Length: 128968, dtype: float64

# %%
df['Amount'].fillna(0,inplace=True)

# %%
df["promotion-ids"]
# Out:
# 0                                                       NaN
# 1         Amazon PLCC Free-Financing Universal Merchant ...
# 2              IN Core Free Shipping 2015/04/08 23-48-5-108
# 3                                                       NaN
# 4                                                       NaN
#                                 ...
# 128963                                                  NaN
# 128964         IN Core Free Shipping 2015/04/08 23-48-5-108
# 128965                                                  NaN
# 128966         IN Core Free Shipping 2015/04/08 23-48-5-108
# 128967         IN Core Free Shipping 2015/04/08 23-48-5-108
# Name: promotion-ids, Length: 128968, dtype: object

# %%
df['promotion-ids'].fillna('no',inplace=True)

# %%
df['ship-city'].fillna('unknown', inplace = True)
df['ship-state'].fillna('unknown', inplace = True)
df['ship-postal-code'].fillna('unknown', inplace = True)

# %%
df.isnull().sum()
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# promotion-ids         0
# B2B                   0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## Categorical Analysis

# %% [markdown]
#  ## 1-Sales by Category

# %%
plt.figure(figsize=(10,5))
cat_sales = df.groupby("Category")["Amount"].sum().sort_values(ascending=False)

sns.barplot(
    x=cat_sales.index,
    y=cat_sales.values,
    palette="Set2"
)

plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 2-Quantity Sold by Category

# %%
plt.figure(figsize=(10,5))
cat_qty = df.groupby("Category")["Qty"].sum()

sns.barplot(
    x=cat_qty.index,
    y=cat_qty.values,
    palette="pastel"
)

plt.title("Quantity Sold by Category")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Sales by Size

# %%
plt.figure(figsize=(8,5))
size_sales = df.groupby("Size")["Amount"].sum()

sns.barplot(
    x=size_sales.index,
    y=size_sales.values,
    palette="coolwarm"
)

plt.title("Sales by Size")
plt.show()

# %% [markdown]
# ## Sales by Fulfilment Method

# %%
plt.figure(figsize=(6,5))
full_sales = df.groupby("Fulfilment")["Amount"].sum()

sns.barplot(
    x=full_sales.index,
    y=full_sales.values,
    palette="viridis"
)

plt.title("Sales by Fulfilment Method")
plt.show()

# %% [markdown]
# ## Courier Status Distribution

# %%
plt.figure(figsize=(8,5))
sns.countplot(
    x="Courier Status",
    data=df,
    palette="Accent"
)

plt.title("Courier Status Distribution")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# ## Sales Trend Over Time

# %%
df["Date"] = pd.to_datetime(df["Date"])
daily_sales = df.groupby("Date")["Amount"].sum()

plt.figure(figsize=(12,5))
plt.plot(
    daily_sales.index,
    daily_sales.values,
    marker="o"
)

plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12068\1714131542.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"])

# %% [markdown]
# ## Quantity Sold Over Time

# %%
daily_qty = df.groupby("Date")["Qty"].sum()

plt.figure(figsize=(12,5))
plt.plot(
    daily_qty.index,
    daily_qty.values,
    marker="o"
)

plt.title("Quantity Sold Over Time")
plt.show()

# %% [markdown]
# ## Distribution Analysis

# %%
plt.figure(figsize=(8,5))
sns.histplot(
    df["Amount"],
    kde=True,
    color="Pink"
)

plt.title("Sales Amount Distribution")
plt.show()

# %% [markdown]
#  ## Quantity Distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(
    df["Qty"],
    kde=True,
    color="salmon"
)

plt.title("Quantity Distribution")
plt.show()

# %% [markdown]
# ## Boxplot of Sales Amount

# %%
plt.figure(figsize=(6,4))
sns.boxplot(
    y=df["Amount"],
    color="lightgreen"
)

plt.title("Boxplot of Sales Amount")
plt.show()

# %% [markdown]
# ## Boxplot Amount by Category

# %%
plt.figure(figsize=(10,5))
sns.boxplot(
    x="Category",
    y="Amount",
    data=df,
    palette="Set2"
)

plt.title("Sales Amount by Category")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Top Products Analysis

# %% [markdown]
# ## Top 10 SKUs by Revenue

# %%
top_sku = df.groupby("SKU")["Amount"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(8,5))
sns.barplot(
    x=top_sku.values,
    y=top_sku.index,
    palette="rocket"
)

plt.title("Top 10 SKUs by Revenue")
plt.xlabel("Total Sales")
plt.show()

# %% [markdown]
# ## Top 10 ASINs by Quantity Sold

# %%
top_asin = df.groupby("ASIN")["Qty"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(8,5))
sns.barplot(
    x=top_asin.values,
    y=top_asin.index,
    palette="mako"
)

plt.title("Top 10 ASINs by Quantity Sold")
plt.show()

# %% [markdown]
# ## B2B vs B2C Sales

# %%
b2b_sales = df.groupby("B2B")["Amount"].sum()

plt.figure(figsize=(6,6))
plt.pie(
    b2b_sales,
    labels=["B2C", "B2B"],
    autopct="%1.1f%%",
    startangle=90,
    colors=["#66c2a5", "#fc8d62"]
)

plt.title("B2B vs B2C Sales")
plt.show()

# %% [markdown]
# ## Quantity by B2B

# %%
plt.figure(figsize=(6,5))
sns.barplot(
    x="B2B",
    y="Qty",
    data=df,
    estimator=sum,
    palette="Set1"
)

plt.title("Quantity Sold: B2B vs B2C")
plt.show()

# %% [markdown]
# ## Scatter: Quantity vs Amount

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x="Qty",
    y="Amount",
    data=df,
    color="purple"
)

plt.title("Quantity vs Amount")
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(8,5))
sns.heatmap(
    df[["Qty", "Amount", "B2B"]].corr(),
    annot=True,
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap")
plt.show()

# %%
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2888\3034448462.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
